# %% [markdown]
# Task 1

# %%
print("Oliver")
print("123 Street")
print("021 123 456")
# Out:
# Oliver
# 123 Street
# 021 123 456

# %% [markdown]
# Task 2

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Hello Oliver

# %% [markdown]
# Task 3

# %%
num = float(input("Enter a number: "))

print("The number is", num)
print("5 times", num, "is", 5 * num)
print("If you add 3 to", num, "the answer is", num + 3)
print("If you divide 20 by", num, "the answer is", 20 / num)
# Out:
# The number is 1.0
# 5 times 1.0 is 5.0
# If you add 3 to 1.0 the answer is 4.0
# If you divide 20 by 1.0 the answer is 20.0

# %% [markdown]
# Task 4

# %%
inches = float(input("Enter the number of inches: "))

cm = inches * 2.54

print(inches, "inches is equal to", cm, "cm")

# %% [markdown]
# Task 5

# %%
age = int(input("Enter your age: "))

future_age = age + (2037 - 2026)

print("Your current age is", age)
print("In the year 2037 you will be", future_age, "years old")
# Out:
# Your current age is 15
# In the year 2037 you will be 26 years old

# %% [markdown]
# Task 6

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
num3 = float(input("Enter the third number: "))

total = num1 + num2 + num3
average = total / 3

print("The numbers were", num1, ",", num2, "and", num3)
print("The total of these numbers is", total)
print("The average of these numbers is", average)
# Out:
# The numbers were 34.0 , 12.0 and 67.0
# The total of these numbers is 113.0
# The average of these numbers is 37.666666666666664
